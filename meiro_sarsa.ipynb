# %%
# 使用するパッケージの宣言
import numpy as np
import matplotlib.pyplot as plt

# %%
# 初期位置での迷路の様子b

# 図を描く大きさと、図の変数名を宣言
fig = plt.figure(figsize=(5,5))
ax = plt.gca()

# 赤い壁を描く
plt.plot([1,1],[0,1],color='red',linewidth=2)
plt.plot([1,2],[2,2],color='red',linewidth=2)
plt.plot([2,2],[2,1],color='red',linewidth=2)
plt.plot([2,3],[1,1],color='red',linewidth=2)

# 状態を示す文字50~58を描く
plt.text(0.5, 2.5, 'S0',size=14,ha='center')
plt.text(1.5, 2.5, 'S1',size=14,ha='center')
plt.text(2.5, 2.5, 'S2',size=14,ha='center')
plt.text(0.5, 1.5, 'S3',size=14,ha='center')
plt.text(1.5, 1.5, 'S4',size=14,ha='center')
plt.text(2.5, 1.5, 'S5',size=14,ha='center')
plt.text(0.5, 0.5, 'S6',size=14,ha='center')
plt.text(1.5, 0.5, 'S7',size=14,ha='center')
plt.text(2.5, 0.5, 'S8',size=14,ha='center')
plt.text(0.5, 2.3, 'START',ha='center')
plt.text(2.5, 0.3, 'GOAL',ha='center')

# 描画画面の設定とメモリを消す設定
ax.set_xlim(0,3)
ax.set_ylim(0,3)
plt.tick_params(axis='both',which='both',bottom='off',top='off',
labelbottom='off',right='off',left='off',labelleft='off')

# 現在地S0に緑丸を描画
line, = ax.plot([0.5], [2.5], marker="o",color='g',markersize=60)
# plt.show()

# %%
# 初期の方策を決定するパラメータtheta_0を設定

# 行は状態0~7、列は移動方向で、上、右、下、左を表す
theta_0 = np.array([[np.nan, 1, 1, np.nan], # S0
                    [np.nan, 1, np.nan, 1], # S1
                    [np.nan, np.nan, 1, 1], # S2
                    [1, 1, 1, np.nan], # S3
                    [np.nan, np.nan, 1, 1], # S4
                    [1, np.nan, np.nan, np.nan], # S5
                    [1, np.nan, np.nan, np.nan], # S6
                    [1, 1, np.nan, np.nan], # S7
                    ])

# %%
# 初期の行動価値関数Qを設定

[a,b]=theta_0.shape # 行と列の数をa,bに格納
Q=np.random.rand(a,b)*theta_0

# %%
# 方策パラメータtheta_0をランダム方策piに変換する関数の定義

def simple_convert_into_pi_from_theta(theta):
    '''単純に割合を計算する'''
    
    [m,n]=theta.shape # thetaの行列サイズを取得
    pi=np.zeros((m,n))
    for i in range(0,m):
        pi[i,:] = theta[i,:]/np.nansum(theta[i,:]) # 割合の計算
        
    pi = np.nan_to_num(pi) # nanを0に変換
    
    return pi

# ランダム行動方策pi_0を求める
pi_0 = simple_convert_into_pi_from_theta(theta_0)

# %%
# 1step移動後の状態sを求める関数を定義

def get_action(s, Q, epsilon, pi_0):
    direction = ["up","right","down","left"]
    
    if np.random.rand()<epsilon:
        # εの確立でランダムに動く
        next_direction = np.random.choice(direction, p=pi_0[s, :])
    else:
        # Qの最大値の行動を採用する
        next_direction = direction[np.nanargmax(Q[s,:])]
 
    # 行動をindexに
    if next_direction == "up":
        action = 0
    elif next_direction == "right":
        action=1
    elif next_direction == "down":
        action=2
    elif next_direction == "left":
        action = 3

    return action

def get_s_next(s, a, Q, epsilon, pi_0):
    direction = ["up","right","down","left"]
    next_direction=direction[a]
    
    if next_direction == "up":
        s_next = s-3 # 上に移動するときは状態の数字が3小さくなる
    elif next_direction == "right":
        s_next = s+1 # 右に移動するときは状態の数字が1大きくなる
    elif next_direction == "down":
        s_next = s+3 # 下に移動するときは状態の数字が3大きくなる
    elif next_direction == "left":
        s_next = s-1 #左に移動するときは状態の数字が１小さくなる
        
    return s_next

# %%
# Sarsaによる行動価値関数Qの更新

def Sarsa(s,a,r,s_next,a_next,Q,eta,gamma):
    
    if s_next == 8: #ゴールした場合
        Q[s,a] = Q[s,a]+eta*(r-Q[s,a])
        
    else:
        Q[s,a]=Q[s,a]+eta*(r+gamma*Q[s_next, a_next]-Q[s,a])
        
    return Q

# %%
# 迷路内をエージェントがゴールするまで移動させる関数の定義
def goal_maze_ret_s_a_Q(Q,epsion,eta,gamma,pi):
    s=0 # スタート地点
    a=a_next=get_action(s,Q,epsilon,pi) # 初期の行動
    s_a_history = [[0, np.nan]] #エージェントの移動を記録するリスト

    while(1): # ゴールするまでループする
        a=a_next # 行動更新
        s_a_history[-1][1] = a
        # 現在の状態（つまり一番最後なのでindex=-1)の行動を代入
        
        s_next = get_s_next(s,a,Q,epsilon,pi)
        # 次の状態を格納
        
        s_a_history.append([s_next, np.nan])
        # 次の状態を代入。行動はまだわからないのでnanにしておく
        
        # 報酬を与え、次の行動を求める
        if s_next == 8: 
            r = 1 #ゴールにたどりついたら報酬を与える
            a_next = np.nan
        else:
            r=0
            a_next = get_action(s_next,Q,epsilon,pi)
            
        # 価値関数を更新
        Q = Sarsa(s,a,r,s_next,a_next,Q,eta,gamma)
    
        # 終了判定
        if s_next == 8: # ゴール地点なら終了
            break
        else:
            s = s_next
    
    return [s_a_history,Q]

# %%
# Sarsaで迷路を解く

eta=0.1 # 学習率
gamma = 0.9 # 時間割引率
epsilon = 0.5 # ε-greedy手法の初期値
v=np.nanmax(Q, axis=1) # 状態ごとに勝ちの最大値を求める
is_continue = True
episode=1

while is_continue: #is_continueがFlaseになるまで繰り返す
    print("エピソード:" + str(episode))
    
    # ε-greedyの値を少しずつ小さくする
    epsilon = epsilon/2
    
    #Sarsaで迷路を解き、移動した履歴と更新したQを求める
    [s_a_history,Q]=goal_maze_ret_s_a_Q(Q,epsilon,eta,gamma,pi_0)
    
    # 状態価値の変化
    new_v = np.nanmax(Q,axis=1) #状態ごとに価値の最大値を求める
    print(np.sum(np.abs(new_v-v))) # 状態価値の変化を出力
    v = new_v
    
    print("迷路を解くのにかかったステップ数は" + str(len(s_a_history)-1)+"です")
    
    # 100エピソード繰り返す
    episode = episode +1
    if episode > 100:
        break
# Out:
# エピソード:1
# 0.35156858128794977
# 迷路を解くのにかかったステップ数は12です
# エピソード:2
# 0.30953885289750305
# 迷路を解くのにかかったステップ数は40です
# エピソード:3
# 0.07207850580759784
# 迷路を解くのにかかったステップ数は12です
# エピソード:4
# 0.046429218484590806
# 迷路を解くのにかかったステップ数は4です
# エピソード:5
# 0.04396598378731076
# 迷路を解くのにかかったステップ数は4です
# エピソード:6
# 0.0413019732326389
# 迷路を解くのにかかったステップ数は4です
# エピソード:7
# 0.03852348023887886
# 迷路を解くのにかかったステップ数は4です
# エピソード:8
# 0.03569953742539733
# 迷路を解くのにかかったステップ数は4です
# エピソード:9
# 0.033657527576880675
# 迷路を解くのにかかったステップ数は4です
# エピソード:10
# 0.033286174734082186
# 迷路を解くのにかかったステップ数は4です
# エピソード:11
# 0.032810897483159684
# 迷路を解くのにかかったステップ数は4です
# エピソード:12
# 0.0322411871189619
# 迷路を解くのにかかったステップ数は4です
# エピソード:13
# 0.03158709354149836
# 迷路を解くのにかかったステップ数は4です
# エピソード:14
# 0.03085888516910218
# 迷路を解くのにかかったステップ数は4です
# エピソード:15
# 0.030066783797277286
# 迷路を解くのにかかったステップ数は4です
# エピソード:16
# 0.029220761646620186
# 迷路を解くのにかかったステップ数は4です
# エピソード:17
# 0.02833038975358987
# 迷路を解くのにかかったステップ数は4です
# エピソード:18
# 0.0274047285037618
# 迷路を解くのにかかったステップ数は4です
# エピソード:19
# 0.026452252523246955
# 迷路を解くのにかかったステップ数は4です
# エピソード:20
# 0.025480803360526993
# 迷路を解くのにかかったステップ数は4です
# エピソード:21
# 0.024497564434556196
# 迷路を解くのにかかったステップ数は4です
# エピソード:22
# 0.023509053618710918
# 迷路を解くのにかかったステップ数は4です
# エピソード:23
# 0.02252112959421082
# 迷路を解くのにかかったステップ数は4です
# エピソード:24
# 0.021539008758547973
# 迷路を解くのにかかったステップ数は4です
# エピソード:25
# 0.020567290029556706
# 迷路を解くのにかかったステップ数は4です
# エピソード:26
# 0.019609985357343374
# 迷路を解くのにかかったステップ数は4です
# エピソード:27
# 0.018670554155955088
# 迷路を解くのにかかったステップ数は4です
# エピソード:28
# 0.017751940204453365
# 迷路を解くのにかかったステップ数は4です
# エピソード:29
# 0.016856609851711668
# 迷路を解くのにかかったステップ数は4です
# エピソード:30
# 0.015986590598330297
# 迷路を解くのにかかったステップ数は4です
# エピソード:31
# 0.015143509329134552
# 迷路を解くのにかかったステップ数は4です
# エピソード:32
# 0.014328629636448653
# 迷路を解くのにかかったステップ数は4です
# エピソード:33
# 0.013542887812643789
# 迷路を解くのにかかったステップ数は4です
# エピソード:34
# 0.012786927204569754
# 迷路を解くのにかかったステップ数は4です
# エピソード:35
# 0.012061130716040869
# 迷路を解くのにかかったステップ数は4です
# エピソード:36
# 0.01136565132073375
# 迷路を解くのにかかったステップ数は4です
# エピソード:37
# 0.010700440509332276
# 迷路を解くのにかかったステップ数は4です
# エピソード:38
# 0.010065274643887623
# 迷路を解くのにかかったステップ数は4です
# エピソード:39
# 0.009459779231105747
# 迷路を解くのにかかったステップ数は4です
# エピソード:40
# 0.008883451156365907
# 迷路を解くのにかかったステップ数は4です
# エピソード:41
# 0.008335678943146907
# 迷路を解くのにかかったステップ数は4です
# エピソード:42
# 0.0078157611194406
# 迷路を解くのにかかったステップ数は4です
# エピソード:43
# 0.007322922784726238
# 迷路を解くのにかかったステップ数は4です
# エピソード:44
# 0.006856330479058204
# 迷路を解くのにかかったステップ数は4です
# エピソード:45
# 0.006415105460529813
# 迷路を解くのにかかったステップ数は4です
# エピソード:46
# 0.0059983354994814775
# 迷路を解くのにかかったステップ数は4です
# エピソード:47
# 0.00560508529783299
# 迷路を解くのにかかったステップ数は4です
# エピソード:48
# 0.005234405640313855
# 迷路を解くのにかかったステップ数は4です
# エピソード:49
# 0.004885341381495989
# 迷路を解くのにかかったステップ数は4です
# エピソード:50
# 0.004556938368730945
# 迷路を解くのにかかったステップ数は4です
# エピソード:51
# 0.0042482493966082835
# 迷路を解くのにかかったステップ数は4です
# エピソード:52
# 0.003958339283589907
# 迷路を解くのにかかったステップ数は4です
# エピソード:53
# 0.0036862891562269295
# 迷路を解くのにかかったステップ数は4です
# エピソード:54
# 0.0034312000209558713
# 迷路を解くのにかかったステップ数は4です
# エピソード:55
# 0.003192195698011213
# 迷路を解くのにかかったステップ数は4です
# エピソード:56
# 0.002968425186589574
# 迷路を解くのにかかったステップ数は4です
# エピソード:57
# 0.0027590645250946677
# 迷路を解くのにかかったステップ数は4です
# エピソード:58
# 0.0025633182051669756
# 迷路を解くのにかかったステップ数は4です
# エピソード:59
# 0.0023804201932714486
# 迷路を解くのにかかったステップ数は4です
# エピソード:60
# 0.0022096346089195418
# 迷路を解くのにかかったステップ数は4です
# エピソード:61
# 0.0020502561041642053
# 迷路を解くのにかかったステップ数は4です
# エピソード:62
# 0.001901609984811592
# 迷路を解くのにかかったステップ数は4です
# エピソード:63
# 0.001763052109886809
# 迷路を解くのにかかったステップ数は4です
# エピソード:64
# 0.0016339686022400768
# 迷路を解くのにかかったステップ数は4です
# エピソード:65
# 0.0015137753997820358
# 迷路を解くのにかかったステップ数は4です
# エピソード:66
# 0.0014019176737238848
# 迷路を解くのにかかったステップ数は4です
# エピソード:67
# 0.001297869137300789
# 迷路を解くのにかかったステップ数は4です
# エピソード:68
# 0.0012011312658189999
# 迷路を解くのにかかったステップ数は4です
# エピソード:69
# 0.0011112324464487289
# 迷路を解くのにかかったステップ数は4です
# エピソード:70
# 0.0010277270739740274
# 迷路を解くのにかかったステップ数は4です
# エピソード:71
# 0.0009501946067106415
# 迷路を解くのにかかったステップ数は4です
# エピソード:72
# 0.0008782385949852589
# 迷路を解くのにかかったステップ数は4です
# エピソード:73
# 0.0008114856929264391
# 迷路を解くのにかかったステップ数は4です
# エピソード:74
# 0.0007495846628408076
# 迷路を解くのにかかったステップ数は4です
# エピソード:75
# 0.0006922053801182715
# 迷路を解くのにかかったステップ数は4です
# エピソード:76
# 0.000639037845423629
# 迷路を解くのにかかったステップ数は4です
# エピソード:77
# 0.0005897912098644653
# 迷路を解くのにかかったステップ数は4です
# エピソード:78
# 0.0005441928178886446
# 迷路を解くのにかかったステップ数は4です
# エピソード:79
# 0.0005019872718174945
# 迷路を解くのにかかったステップ数は4です
# エピソード:80
# 0.00046293552118625847
# 迷路を解くのにかかったステップ数は4です
# エピソード:81
# 0.00042681397940880217
# 迷路を解くのにかかったステップ数は4です
# エピソード:82
# 0.00039341366970979674
# 迷路を解くのにかかったステップ数は4です
# エピソード:83
# 0.0003625394017680028
# 迷路を解くのにかかったステップ数は4です
# エピソード:84
# 0.00033400898008084656
# 迷路を解くのにかかったステップ数は4です
# エピソード:85
# 0.0003076524446822271
# 迷路を解くのにかかったステップ数は4です
# エピソード:86
# 0.0002833113445223079
# 迷路を解くのにかかったステップ数は4です
# エピソード:87
# 0.0002608380435400459
# 迷路を解くのにかかったステップ数は4です
# エピソード:88
# 0.00024009505922828467
# 迷路を解くのにかかったステップ数は4です
# エピソード:89
# 0.00022095443328828956
# 迷路を解くのにかかったステップ数は4です
# エピソード:90
# 0.00020329713380973224
# 迷路を解くのにかかったステップ数は4です
# エピソード:91
# 0.00018701248827757144
# 迷路を解くのにかかったステップ数は4です
# エピソード:92
# 0.00017199764659237005
# 迷路を解くのにかかったステップ数は4です
# エピソード:93
# 0.00015815707321265027
# 迷路を解くのにかかったステップ数は4です
# エピソード:94
# 0.00014540206745117246
# 迷路を解くのにかかったステップ数は4です
# エピソード:95
# 0.00013365031091561175
# 迷路を解くのにかかったステップ数は4です
# エピソード:96
# 0.00012282544104180726
# 迷路を解くのにかかったステップ数は4です
# エピソード:97
# 0.00011285664965354769
# 迷路を解くのにかかったステップ数は4です
# エピソード:98
# 0.00010367830546542667
# 迷路を解くのにかかったステップ数は4です
# エピソード:99
# 9.5229599444413e-05
# 迷路を解くのにかかったステップ数は4です
# エピソード:100
# 8.745421196110215e-05
# 迷路を解くのにかかったステップ数は4です
